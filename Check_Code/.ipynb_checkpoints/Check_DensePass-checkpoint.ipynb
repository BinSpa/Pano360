# %%
import os
import re
import json
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
image_dir = "../../../PanoData/DensePASS/leftImg8bit/val"
output_dir = "../../../PanoCode/SpatialR360_DG/output/DensePass"
image_name = "1_.png"
output_name = f"densepass_{image_name.split('.')[0]}.json"
output_path = os.path.join(output_dir, output_name)
image_path = os.path.join(image_dir, image_name)

# %%
image = Image.open(image_path)
print(image.size)
with open(output_path, 'r', encoding='utf-8') as f:
    result = json.load(f)
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15, 10))
axs.imshow(image)
axs.axis('off')
plt.show()
# Out:
# (2048, 400)

# %%
with open(output_path, 'r', encoding='utf-8') as f:
    result = json.load(f)
gen_data = result["reasoning"][1]
print(f"data:\n {gen_data}\n")
# Out:
# data:
#  {'question': 'Which building is located at the central point of the panorama image, and what are its spatial relationships with the adjacent buildings?', 'reasoning_chain': "1. The central point of the panorama is approximately at the intersection where the two large roads meet, slightly to the right of the tree in the center.  \n2. At this central point, there is a tall, rectangular red-brick building with many windows.  \n3. To the left of this central building (from the viewer's perspective), there is another brick building (with the curved corner and 'No Exit' sign).  \n4. To the right of the central building, there is a large industrial-looking building with a metal exterior and a smokestack.  \n5. The central building is thus bordered by the brick building on the left and the industrial building on the right, and sits at the intersection of two main roads.", 'final_answer': 'The central building is a tall red-brick structure with many windows, flanked by a brick building on its left and an industrial building with a smokestack on its right.'}
