# %%
import os
import re
import json
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
image_dir = "../../../PanoData/DensePASS/leftImg8bit/val"
output_dir = "../../../PanoCode/SpatialR360_DG/output/DensePass"
image_name = "114_.png"
output_name = f"densepass_{image_name.split('.')[0]}.json"
output_path = os.path.join(output_dir, output_name)
image_path = os.path.join(image_dir, image_name)

# %%
image = Image.open(image_path)
image.save('image.png')
print(image.size)
with open(output_path, 'r', encoding='utf-8') as f:
    result = json.load(f)
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(15, 10))
axs.imshow(image)
axs.axis('off')
plt.show()
# Out:
# (2048, 400)

# %%
with open(output_path, 'r', encoding='utf-8') as f:
    result = json.load(f)
reasoning_data = result["reasoning"]
print(len(reasoning_data))
for re in reasoning_data:
    print("Question:\n{}".format(re["question"]))
    print("Chain:\n{}".format(re["reasoning_chain"]))
    print("Final:\n{}".format(re["final_answer"]))
# Out:
# 5
# Question:
# Is the red car closer to the multi-storey brick building or to the single-storey brick building with the green mesh fence?
# Chain:
# The red car is visible near the center-left section of the panorama. There are two types of buildings nearby: a multi-storey brick building to the left and a single-storey brick building with a green mesh fence to the right. The car is parked adjacent to the multi-storey building, with very little distance between them. In contrast, there is a road and green vegetation separating the car from the single-storey building and mesh fence, which are further to the right. The spatial relationship in the panorama makes it clear that the car is immediately next to the multi-storey building.
# Final:
# The red car is closer to the multi-storey brick building.
# Question:
# If a person starts at the single-storey building with the green mesh fence and wants to walk to the multi-storey building, which direction should they head?
# Chain:
# ...
